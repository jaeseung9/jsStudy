# %% [markdown]
# # Pinecone Vector DB

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# 파일 로드
from langchain_community.document_loaders import CSVLoader

loader = CSVLoader('./winemag-data-130k-v2.csv', encoding= 'utf-8')

documents = loader.load()  # 모든 행을 Document 객체 리스트로 변환

print(f'총 문서 수: {len(documents)}')
print(documents[0])  # 첫 번째 문서 출력
# Out:
# 총 문서 수: 129971
# page_content=': 0
# country: Italy
# description: Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity.
# designation: Vulkà Bianco
# points: 87
# price:
# province: Sicily & Sardinia
# region_1: Etna
# region_2:
# taster_name: Kerin O’Keefe
# taster_twitter_handle: @kerinokeefe
# title: Nicosia 2013 Vulkà Bianco  (Etna)
# variety: White Blend
# winery: Nicosia' metadata={'source': './winemag-data-130k-v2.csv', 'row': 0}

# %%
# 임베딩 모델 생성
from langchain_openai.embeddings import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# %%
# %pip install langchain-pinecone

# %%
# Pinecone 클라이언트 생성
import os
from langchain_pinecone import PineconeVectorStore

PINECONE_INDEX_NAME = os.getenv("PINECONE_INDEX_NAME")
PINECONE_NAMESPACE = os.getenv("PINECONE_NAMESPACE")
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")


vector_db = PineconeVectorStore.from_documents(
    documents[:10],
    embeddings,
    index_name=PINECONE_INDEX_NAME,
    namespace=PINECONE_NAMESPACE,
    pinecone_api_key=PINECONE_API_KEY
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[23], line 10
#       6 PINECONE_NAMESPACE = os.getenv("PINECONE_NAMESPACE")
#       7 PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
# ---> 10 vector_db = PineconeVectorStore.from_documents(
#      11     documents[:10],
#      12     embeddings,
#      13     index_name=PINECONE_INDEX_NAME,
#      14     namespace=PINECONE_NAMESPACE,
#      15     pinecone_api_key=PINECONE_API_KEY
#      16 )
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\langchain_core\vectorstores\base.py:813, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     810     if any(ids):
#     811         kwargs["ids"] = ids
# --> 813 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\langchain_pinecone\vectorstores.py:978, in PineconeVectorStore.from_texts(cls, texts, embedding, metadatas, ids, batch_size, text_key, namespace, index_name, upsert_kwargs, pool_threads, embeddings_chunk_size, async_req, id_prefix, **kwargs)
#     975 pinecone_index = cls.get_pinecone_index(index_name, pool_threads)
#     976 pinecone = cls(pinecone_index, embedding, text_key, namespace, **kwargs)
# --> 978 pinecone.add_texts(
#     979     texts,
#     980     metadatas=metadatas,
#     981     ids=ids,
#     982     namespace=namespace,
#     983     batch_size=batch_size,
#     984     embedding_chunk_size=embeddings_chunk_size,
#     985     async_req=async_req,
#     986     id_prefix=id_prefix,
#     987     **(upsert_kwargs or {}),
#     988 )
#     989 return pinecone
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\langchain_pinecone\vectorstores.py:357, in PineconeVectorStore.add_texts(self, texts, metadatas, ids, namespace, batch_size, embedding_chunk_size, async_req, id_prefix, **kwargs)
#     355 chunk_ids = ids[i : i + embedding_chunk_size]
#     356 chunk_metadatas = metadatas[i : i + embedding_chunk_size]
# --> 357 embeddings = self._embedding.embed_documents(chunk_texts)
#     358 vector_tuples = list(zip(chunk_ids, embeddings, chunk_metadatas))
#     359 if async_req:
#     360     # Runs the pinecone upsert asynchronously.
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\langchain_openai\embeddings\base.py:709, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     706 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     707 # This could be optimized to avoid double work when all texts are short enough.
#     708 engine = cast(str, self.deployment)
# --> 709 return self._get_len_safe_embeddings(
#     710     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     711 )
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\langchain_openai\embeddings\base.py:576, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     574 # Make API call with this batch
#     575 batch_tokens = tokens[i:batch_end]
# --> 576 response = self.client.create(input=batch_tokens, **client_kwargs)
#     577 if not isinstance(response, dict):
#     578     response = response.model_dump()
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\openai\resources\embeddings.py:132, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     126             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     127                 base64.b64decode(data), dtype="float32"
#     128             ).tolist()
#     130     return obj
# --> 132 return self._post(
#     133     "/embeddings",
#     134     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     135     options=make_request_options(
#     136         extra_headers=extra_headers,
#     137         extra_query=extra_query,
#     138         extra_body=extra_body,
#     139         timeout=timeout,
#     140         post_parser=parser,
#     141     ),
#     142     cast_to=CreateEmbeddingResponse,
#     143 )
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for text-embedding-3-small in organization org-tEkN7kkb6kFBT1jbUmEAuN0y on tokens per min (TPM): Limit 1000000, Used 1000000, Requested 1444. Please try again in 86ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
