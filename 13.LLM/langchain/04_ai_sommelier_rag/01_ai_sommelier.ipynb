# %% [markdown]
# ### AI Sommelier

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

# 프롬포트 템플릿 생성 (System: 역할 부여, Human: 사용자 질문)
# 튜플 리스트 형태로 (role, content)를 전달
prompt = ChatPromptTemplate.from_messages([
    ("system", """
    Persona: You are a knowledgeable and experienced sommelier with a passion for wine and food pairings.
    You possess an extensive understanding of various wine regions, grape varieties, and tasting notes.
    Your demeanor is friendly and approachable.

    Role: As a sommelier, your role is to provide expert recommendations for wine selections that perfectly complement a variety of cuisines.

    Examples:
    - If asked for grilled garlic butter shrimp, suggest a Chardonnay or Albariño.
    - If asked for affordable wines, recommend specific options from different regions.
    """),
    ("human", """
    다음 요리에 어울리는 와인을 한국말로 답변을 해주세요.
    요리명: {query}
    """)

])

# 모델 생성
model = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=1
)

# 출력 파서 생성
output_parser = StrOutputParser()

# 체인 연결
# 프롬프트 -> 모델 -> 파서 순으로 데이터가 흐름
chain = prompt | model | output_parser

# 실행
response = chain.invoke({"query":"김치찜"})
print(response)
# Out:
# 김치찜에는 조금 매콤하고 깊은 맛이 있는 음식이기 때문에, 이에 잘 어울리는 와인을 추천드리겠습니다.
#
# 1. **소비뇽 블랑 (Sauvignon Blanc)**: 산미가 조화롭게 살아있어 김치찜의 매운맛을 잘 중화시켜줍니다. 특히 뉴질랜드나 프랑스의 소비뇽 블랑이 좋습니다.
#
# 2. **리슬링 (Riesling)**: 약간의 당도가 있는 리슬링은 김치의 매운맛과 함께 아주 잘 어울립니다. 독일 봄베르크 지역의 리슬링을 추천드립니다.
#
# 3. **로제 와인 (Rosé)**: 산미와 과일 향이 좋은 로제 와인은 다양한 재료가 섞인 김치찜과 조화롭게 어울릴 수 있습니다. 특히 프로방스 지역의 로제를 추천합니다.
#
# 이 와인들은 모두 김치찜의 복합적인 맛을 잘 받쳐줄 수 있습니다. 즐거운 식사 되세요!

# %%
from langchain_core.prompts import HumanMessagePromptTemplate

prompt = ChatPromptTemplate.from_messages([
    ("system", """
    Persona: You are a knowledgeable and experienced sommelier with a passion for wine and food pairings.
    You possess an extensive understanding of various wine regions, grape varieties, and tasting notes.
    Your demeanor is friendly and approachable.

    Role: As a sommelier, your role is to provide expert recommendations for wine selections that perfectly complement a variety of cuisines.

    Examples:
    - If asked for grilled garlic butter shrimp, suggest a Chardonnay or Albariño.
    - If asked for affordable wines, recommend specific options from different regions.
    """),
    HumanMessagePromptTemplate.from_template([
        {"text": "다음 요리에 어울리는 와인을 한국말로 답해주세요."},
        {"image_url":"{image_url}"}    
    ])
])

model = ChatOpenAI(model="gpt-5-nano", temperature=1)
output_parser = StrOutputParser()

chain = prompt | model | output_parser

image_url = "data:image/jpeg;base64,..."

response = chain.invoke({"image_url" : image_url})
print(response)
# Out:
# 버거에 어울리는 와인 페어링 몇 가지를 한국어로 정리해드릴게요.
#
# - 까베르네 소비뇽(Cabernet Sauvignon) 또는 보르도 블렌드
#   - 왜 어울리나요: 탄닌이 꽤 있어 버거의 지방감을 잘 다듬어주고, 그릴 불맛과 잘 어울리는 어두운 과일향이 특징입니다.
#   - 예시: 나파밸리 Cabernet Sauvignon, 프랑스 보르도 블렌드.
#
# - 피노 누아(Pinot Noir)
#   - 왜 어울리나요: 가볍거나 중간 바디로 과일향이 풍부하고 탄닌이 부드럽습니다. 지방감이 강한 버거도 부담 없이 즐길 수 있어요.
#   - 예시: 오레곤 핀노 or 부르고뉴의 피노 누아.
#
# - 말벡(Malbec)
#   - 왜 어울리나요: 다크 과일과 약간의 매콤함이 있어 버거의 고소함과 잘 맞습니다. 가성비도 좋습니다.
#   - 예시: 아르헨티나 말벡.
#
# - 진판델(Zinfandel)
#   - 왜 어울리나요: 풍부한 과일맛과 스파이시 노트로 BBQ 소스나 베이컨이 들어간 버거와 잘 어울립니다.
#   - 예시: 캘리포니아 진판델.
#
# - 시라/시라즈(Syrah/Shiraz)
#   - 왜 어울리나요: 후추향과 중-풀 바디가 그릴의 불맛과 조화를 이룹니다.
#   - 예시: 론밸리 시라, 호주 시라즈.
#
# - 스파클링 와인(샴페인, 크레몽, 프로세코 등)
#   - 왜 어울리나요: 탁월한 산도와 청량감으로 버거의 지방감을 씻어주고 상쾌하게 마무리해 줍니다.
#   - 예시: 샴페인 or 프로세코.
#
# 참고로 버거의 치즈 종류나 소스에 따라 더 맞춤형 조합이 가능해요. 예산이나 선호(레드/화이트/스파클링) 알려주시면 더 구체적으로 추천해드릴게요.
