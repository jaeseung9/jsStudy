# %% [markdown]
# ### AI Sommelier RAG

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# #### 1. 요리 풍미 묘사 (Image Analysis)

# %%
from langchain_core.prompts import ChatPromptTemplate, HumanMessagePromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

def describe_dish_flavor(query):
    # 프롬포트 정의
    prompt = ChatPromptTemplate.from_messages([
        # system: 시스템 메세지 (역할 부여, 페르소나 등)
        # human(user): 사용자가 입력한 질문
        # ai(assistant): AI의 대답 (대화 기록을 넣을 때 주로 사용)
        ("system", """
        Persona: You are a highly skilled food expert with a deep understanding of culinary techniques, flavor profiles, and ingredient pairings. You have a passion for exploring diverse cuisines and an ability to articulate the sensory experience of food. Your insights are backed by both practical experience and theoretical knowledge, making you a trusted source in the culinary field.

Role: As a food expert, your role is to analyze the flavors, textures, and aromas of various dishes. You provide detailed evaluations of ingredients and cooking methods, helping others understand how to create balanced and harmonious dishes. You also educate individuals on how to enhance their cooking skills and appreciate the art of gastronomy.

Examples:

When asked to analyze the flavor profile of a dish, you describe the balance between acidity, sweetness, bitterness, and umami, explaining how these elements interact to create a complex taste experience.
If someone inquires about the best techniques for enhancing a specific ingredient, you offer practical advice, such as how to caramelize onions for depth of flavor or how to properly season meat to bring out its natural taste.
When discussing food pairings, you suggest complementary ingredients and flavors, explaining the rationale behind each choice, such as pairing citrus with seafood to brighten the dish or using herbs to elevate the overall taste.
        """),

        ("user", "이미지의 요리명과 풍미를 한 문장으로 요약해주세요.")
    ])

    # 이미지 URL 메시지 추가
    prompt += HumanMessagePromptTemplate.from_template([query])

    # 모델 설정
    model = ChatOpenAI(model="gpt-4o", temperature=0)

    output_parser = StrOutputParser()

    # 체인
    chain = prompt | model | output_parser

    return chain

# %%
from langchain_core.runnables import RunnableLambda

chain = RunnableLambda(describe_dish_flavor)

chain.invoke({"image_url":"data:image/jpeg;base64,..."})
# Out:
# '이 요리는 간장 양념 치킨으로, 바삭한 튀김 옷에 짭조름하고 달콤한 간장 소스가 어우러져 깊은 감칠맛을 선사합니다.'

# %% [markdown]
# # 2. 리뷰에서 와인 검색(Retrieval)

# %%
from langchain_openai.embeddings import OpenAIEmbeddings
from langchain_pinecone import PineconeVectorStore
import os

# 환경 변수 로드

PINECONE_INDEX_NAME = os.getenv("PINECONE_INDEX_NAME")
PINECONE_NAMESPACE = os.getenv("PINECONE_NAMESPACE")
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")

def search_wines(query):

    """
    Args:
        query (str): 요리 풍미 묘사 텍스트
    Returns:
        dict: 다음 단계로 넘겨줄 데이터 셋 (요리 묘사 + 검색된 와인 리뷰둘)
    """
    embeddings = OpenAIEmbeddings(
        model="text-embedding-3-small",
        openai_api_key=os.getenv("OPENAI_API_KEY")
    )

    vector_db = PineconeVectorStore(
        embedding=embeddings,
        index_name=PINECONE_INDEX_NAME,
        namespace=PINECONE_NAMESPACE,
        pinecone_api_key=PINECONE_API_KEY
    )

    # 유사도 검색 실행
    results = vector_db.similarity_search(query, k=5, namespace=PINECONE_NAMESPACE)

    # dish_flavor: 원래 요리 설명 (그대로 전달)
    # wine_reviews: 검색된 와인 리뷰들을 하나의 문자열로 합침
    return {
        "dish_flavor": query,
        "wine_reviews": "\n".join([doc.page_content for doc in results])
    }

# %%
chain = RunnableLambda(search_wines)
chain.invoke('이 요리는 간장 양념 치킨으로, 바삭한 튀김 옷에 짭조름하고 달콤한 간장 소스가 어우러져 깊은 감칠맛을 선사합니다.')
# Out:
# {'dish_flavor': '이 요리는 간장 양념 치킨으로, 바삭한 튀김 옷에 짭조름하고 달콤한 간장 소스가 어우러져 깊은 감칠맛을 선사합니다.',
#  'wine_reviews': ": 571\ncountry: US\ndescription: This wine tastes fresh and brisk, like apricots and lemons, yet a silky-smooth texture adds depth and interest to make it more than just a one-note, fruity style of wine. It comes from an over-achieving winery located one county inland from Napa.\ndesignation: \npoints: 89\nprice: 25.0\nprovince: California\nregion_1: Yolo County\nregion_2: Central Valley\ntaster_name: Jim Gordon\ntaster_twitter_handle: @gordone_cellars\ntitle: Berryessa Gap 2015 Albariño (Yolo County)\nvariety: Albariño\nwinery: Berryessa Gap\n: 494\ncountry: US\ndescription: This is intensely aromatic, with loads of tropical fruit, apple blossom and white peach notes on the nose and palate. It's fresh, tasty and big in body, yet deftly balanced. Soft, lemony acidity on the midpalate gets a boost of citrus rind and saline on the finish.\ndesignation: \npoints: 87\nprice: 12.0\nprovince: New York\nregion_1: Finger Lakes\nregion_2: Finger Lakes\ntaster_name: Anna Lee C. Iijima\ntaster_twitter_handle: \ntitle: Knapp 2011 Chardonnay (Finger Lakes)\nvariety: Chardonnay\nwinery: Knapp\n: 265\ncountry: South Africa\ndescription: Fairly intense and flavorful, this Chard expresses assertive aromas and flavors of wood-grilled peaches, buttercream frosting, lemon custard and toasted brioche. Medium weight in the mouth with good balance and a touch of baking spice on the close.\ndesignation: Nine Yards\npoints: 89\nprice: 40.0\nprovince: Stellenbosch\nregion_1: \nregion_2: \ntaster_name: Lauren Buzzeo\ntaster_twitter_handle: @laurbuzz\ntitle: Jardin 2009 Nine Yards Chardonnay (Stellenbosch)\nvariety: Chardonnay\nwinery: Jardin\n: 806\ncountry: US\ndescription: Very smooth, almost thick, this is a rich wine in flavor and mouthfeel. It practically oozes over the palate, dripping with ripe pineapple, vanilla and cream, and coats every corner of the mouth before lingering through a long finish. It's full bodied, soft and concentrated.\ndesignation: Small Lot\npoints: 90\nprice: 27.0\nprovince: California\nregion_1: Sierra Foothills\nregion_2: Sierra Foothills\ntaster_name: Jim Gordon\ntaster_twitter_handle: @gordone_cellars\ntitle: Iron Hub 2014 Small Lot Chardonnay (Sierra Foothills)\nvariety: Chardonnay\nwinery: Iron Hub\n: 442\ncountry: US\ndescription: Voluptuous blackberry and plum flavors are edged by hints of bitter coffee and spice in this richly bodied wine. Fringed by a bare feather of tannins, it's luscious in mouthfeel, with an unctuousness that persists luxuriously on the palate.\ndesignation: Caya\npoints: 89\nprice: 35.0\nprovince: New York\nregion_1: Long Island\nregion_2: Long Island\ntaster_name: Anna Lee C. Iijima\ntaster_twitter_handle: \ntitle: Wölffer 2013 Caya Cabernet Franc (Long Island)\nvariety: Cabernet Franc\nwinery: Wölffer"}

# %% [markdown]
# ### 3. 최종 와인 추천 (Generation)

# %%
def recommend_wines(query):
    # 프롬프트 정의
    prompt = ChatPromptTemplate.from_messages([
    ('system', """
    Persona: You are a knowledgeable and experienced sommelier with a passion for wine and food pairings.
    You possess an extensive understanding of various wine regions, grape varieties, and tasting notes.
    Your demeanor is friendly and approachable.

    Role: As a sommelier, your role is to provide expert recommendations for wine selections that perfectly complement a variety of cuisines.

    Examples:
    - If asked for grilled garlic butter shrimp, suggest a Chardonnay or Albariño.
    - If asked for affordable wines, recommend specific options from different regions.
    """),
    HumanMessagePromptTemplate.from_template("""
    와인페어링 추천에 아래의 요리와 풍미, 와인리뷰만을 참고하여 답변해주세요.
     요리와 풍미:
    {dish_flavor}
     와인리뷰:
    {wine_reviews}
    """)
    ])

    model = ChatOpenAI(
        model="gpt-5-nano",
        temperature=1,
        openai_api_key=os.getenv("OPENAI_API_KEY")
    )

    chain = prompt | model | StrOutputParser()
    
    return chain

# %% [markdown]
# ### 전체 파이프라인 연결 (LCEL)

# %%
from langchain_core.runnables import RunnableLambda

chain = RunnableLambda(describe_dish_flavor) | RunnableLambda(search_wines) | RunnableLambda(recommend_wines)

# 실행
image_url = "https://www.chosun.com/resizer/v2/IZOXUQBP4QVT4ONUPAIDA6347M.jpg?auth=02348480da1037da93881cc28736549fa9122b7bd614eab0d5d170fd0f1a5c7c&width=464"

response = chain.invoke({"image_url": image_url})

print(response)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[21], line 8
#       5 # 실행
#       6 image_url = "https://wimg.heraldcorp.com/content/default/2019/09/27/20190927000594_0.jpg"
# ----> 8 response = chain.invoke({"image_url": image_url})
#      10 print(response)
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\langchain_core\runnables\base.py:3149, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3147 with set_config_context(config) as context:
#    3148     if i == 0:
# -> 3149         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3150     else:
#    3151         input_ = context.run(step.invoke, input_, config)
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\langchain_core\runnables\base.py:4880, in RunnableLambda.invoke(self, input, config, **kwargs)
#    4865 """Invoke this `Runnable` synchronously.
#    4866
#    4867 Args:
#    (...)   4877
#    4878 """
#    4879 if hasattr(self, "func"):
# -> 4880     return self._call_with_config(
#    4881         self._invoke,
#    4882         input,
#    4883         ensure_config(config),
#    4884         **kwargs,
#    4885     )
#    4886 msg = "Cannot invoke a coroutine function synchronously.Use `ainvoke` instead."
#    4887 raise TypeError(msg)
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\langchain_core\runnables\base.py:2058, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    2054     child_config = patch_config(config, callbacks=run_manager.get_child())
#    2055     with set_config_context(child_config) as context:
#    2056         output = cast(
#    2057             "Output",
# -> 2058             context.run(
#    2059                 call_func_with_variable_args,  # type: ignore[arg-type]
#    2060                 func,
#    2061                 input_,
#    2062                 config,
#    2063                 run_manager,
#    2064                 **kwargs,
#    2065             ),
#    2066         )
#    2067 except BaseException as e:
#    2068     run_manager.on_chain_error(e)
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\langchain_core\runnables\config.py:433, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     431 if run_manager is not None and accepts_run_manager(func):
#     432     kwargs["run_manager"] = run_manager
# --> 433 return func(input, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\langchain_core\runnables\base.py:4748, in RunnableLambda._invoke(self, input_, run_manager, config, **kwargs)
#    4744         msg = (
#    4745             f"Recursion limit reached when invoking {self} with input {input_}."
#    4746         )
#    4747         raise RecursionError(msg)
# -> 4748     output = output.invoke(
#    4749         input_,
#    4750         patch_config(
#    4751             config,
#    4752             callbacks=run_manager.get_child(),
#    4753             recursion_limit=recursion_limit - 1,
#    4754         ),
#    4755     )
#    4756 return cast("Output", output)
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\langchain_core\runnables\base.py:3151, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3149                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3150             else:
# -> 3151                 input_ = context.run(step.invoke, input_, config)
#    3152 # finish the root run
#    3153 except BaseException as e:
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\langchain_core\language_models\chat_models.py:398, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     384 @override
#     385 def invoke(
#     386     self,
#    (...)    391     **kwargs: Any,
#     392 ) -> AIMessage:
#     393     config = ensure_config(config)
#     394     return cast(
#     395         "AIMessage",
#     396         cast(
#     397             "ChatGeneration",
# --> 398             self.generate_prompt(
#     399                 [self._convert_input(input)],
#     400                 stop=stop,
#     401                 callbacks=config.get("callbacks"),
#     402                 tags=config.get("tags"),
#     403                 metadata=config.get("metadata"),
#     404                 run_name=config.get("run_name"),
#     405                 run_id=config.pop("run_id", None),
#     406                 **kwargs,
#     407             ).generations[0][0],
#     408         ).message,
#     409     )
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\langchain_core\language_models\chat_models.py:1117, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1108 @override
#    1109 def generate_prompt(
#    1110     self,
#    (...)   1114     **kwargs: Any,
#    1115 ) -> LLMResult:
#    1116     prompt_messages = [p.to_messages() for p in prompts]
# -> 1117     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\langchain_core\language_models\chat_models.py:927, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     924 for i, m in enumerate(input_messages):
#     925     try:
#     926         results.append(
# --> 927             self._generate_with_cache(
#     928                 m,
#     929                 stop=stop,
#     930                 run_manager=run_managers[i] if run_managers else None,
#     931                 **kwargs,
#     932             )
#     933         )
#     934     except BaseException as e:
#     935         if run_managers:
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\langchain_core\language_models\chat_models.py:1221, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1219     result = generate_from_stream(iter(chunks))
#    1220 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1221     result = self._generate(
#    1222         messages, stop=stop, run_manager=run_manager, **kwargs
#    1223     )
#    1224 else:
#    1225     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\langchain_openai\chat_models\base.py:1380, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1378     if raw_response is not None and hasattr(raw_response, "http_response"):
#    1379         e.response = raw_response.http_response  # type: ignore[attr-defined]
# -> 1380     raise e
#    1381 if (
#    1382     self.include_response_headers
#    1383     and raw_response is not None
#    1384     and hasattr(raw_response, "headers")
#    1385 ):
#    1386     generation_info = {"headers": dict(raw_response.headers)}
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\langchain_openai\chat_models\base.py:1375, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1368         return _construct_lc_result_from_responses_api(
#    1369             response,
#    1370             schema=original_schema_obj,
#    1371             metadata=generation_info,
#    1372             output_version=self.output_version,
#    1373         )
#    1374     else:
# -> 1375         raw_response = self.client.with_raw_response.create(**payload)
#    1376         response = raw_response.parse()
#    1377 except Exception as e:
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\openai\_legacy_response.py:364, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     360 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     362 kwargs["extra_headers"] = extra_headers
# --> 364 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\openai\resources\chat\completions\completions.py:1192, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1145 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1146 def create(
#    1147     self,
#    (...)   1189     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1190 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1191     validate_response_format(response_format)
# -> 1192     return self._post(
#    1193         "/chat/completions",
#    1194         body=maybe_transform(
#    1195             {
#    1196                 "messages": messages,
#    1197                 "model": model,
#    1198                 "audio": audio,
#    1199                 "frequency_penalty": frequency_penalty,
#    1200                 "function_call": function_call,
#    1201                 "functions": functions,
#    1202                 "logit_bias": logit_bias,
#    1203                 "logprobs": logprobs,
#    1204                 "max_completion_tokens": max_completion_tokens,
#    1205                 "max_tokens": max_tokens,
#    1206                 "metadata": metadata,
#    1207                 "modalities": modalities,
#    1208                 "n": n,
#    1209                 "parallel_tool_calls": parallel_tool_calls,
#    1210                 "prediction": prediction,
#    1211                 "presence_penalty": presence_penalty,
#    1212                 "prompt_cache_key": prompt_cache_key,
#    1213                 "prompt_cache_retention": prompt_cache_retention,
#    1214                 "reasoning_effort": reasoning_effort,
#    1215                 "response_format": response_format,
#    1216                 "safety_identifier": safety_identifier,
#    1217                 "seed": seed,
#    1218                 "service_tier": service_tier,
#    1219                 "stop": stop,
#    1220                 "store": store,
#    1221                 "stream": stream,
#    1222                 "stream_options": stream_options,
#    1223                 "temperature": temperature,
#    1224                 "tool_choice": tool_choice,
#    1225                 "tools": tools,
#    1226                 "top_logprobs": top_logprobs,
#    1227                 "top_p": top_p,
#    1228                 "user": user,
#    1229                 "verbosity": verbosity,
#    1230                 "web_search_options": web_search_options,
#    1231             },
#    1232             completion_create_params.CompletionCreateParamsStreaming
#    1233             if stream
#    1234             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1235         ),
#    1236         options=make_request_options(
#    1237             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1238         ),
#    1239         cast_to=ChatCompletion,
#    1240         stream=stream or False,
#    1241         stream_cls=Stream[ChatCompletionChunk],
#    1242     )
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Admin\miniconda3\envs\pystudy_env\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': 'Timeout while downloading https://wimg.heraldcorp.com/content/default/2019/09/27/20190927000594_0.jpg.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_image_url'}}
