# %% [markdown]
# ### STT(Speech-to-Text)
# Whisper

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI

client = OpenAI()
# 오디오 파일은 텍스트가 아닌 바이너리 데이터이므로, 'rb'(Read Binary)모드로 열어서 전송해야 한다.
with open("output.mp3", "rb") as f:
    transcriptions = client.audio.transcriptions.create(
        model="whisper-1",
        file=f
    )
    # print(transcriptions)
    print(transcriptions.text)
# Out:
# 화요일인 23일 오후부터 24일 새벽 사이 전국 대부분 지역에 비가 내리겠다. 경기 북부와 강원 내륙 산지에는 비 또는 눈이 올 수 있다. 일부 경상권은 24일 아침까지, 제주도는 오후까지 비가 이어지는 곳이 있겠다.
